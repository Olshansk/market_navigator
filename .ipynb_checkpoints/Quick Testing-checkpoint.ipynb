# %%
# %load_ext autoreload
# %autoreload 2

# %%
from iexfinance.refdata import get_symbols, get_iex_symbols
import os
import pandas as pd
from datetime import datetime, date
from iexfinance.stocks import get_historical_data
from dateutil.relativedelta import relativedelta

# %%
# Used to log the `MESSAGES USED` in `_IEXBAse`.
# https://addisonlynch.github.io/iexfinance/stable/logging.html
import logging
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)
logging.debug("test")
os.environ["IEX_LOG_LEVEL"] = "DEBUG"
# Out:
# DEBUG:root:test

# %%
IEX_TOKEN = "Tpk_57fa15c2c86b4dadbb31e0c1ad1db895"
os.environ["IEX_API_VERSION"] = "iexcloud-sandbox"

# %%
symbols = get_symbols(token=IEX_TOKEN)[0:10]
symbols
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): sandbox.iexapis.com:443
# DEBUG:urllib3.connectionpool:https://sandbox.iexapis.com:443 "GET /stable/ref-data/symbols?token=Tpk_57fa15c2c86b4dadbb31e0c1ad1db895 HTTP/1.1" 200 None
#   symbol exchange                                               name  \
# 0      A      SYN                          ToleIigtncel eon.hcAin sg
# 1     AA      YNS                                        .a rClcooAp
# 2    AAA      PSE                     Fyn Ftd FtAiBLPAsor iTCOEor ir
# 3   AAAU      PSE                       hdail lP GFEtnrc teMP oiyhTs
# 4   AACG      NAS                lanGdlDevtitbCaAr Ro A  riopeoySsTA
# 5   AACQ      ASN                     nsaAiCoAuisricq sttiIuscnA  l
# 6  AACQU      SNA   i sfiW c3A+2r/AnUcsi3S oq no1uh7n0n st i  Iui...
# 7  AACQW      SAN  - ni2qca5sctrnn2oi-auAtrn2su.7 A0q0o.cAs t1Ii ...
# 8   AADR      ESP                SioahhvAseygDReF  T rrsrostd WiEADr
# 9   AAIC      NYS           AspnAsl CInale ntsrigrt to CsAvmso.ten e
#
#          date type                 iexId region currency  isEnabled  \
# 0  2020-11-27   cs  IEX_46574843354B2D52     US      USD       True
# 1  2020-11-27   cs  IEX_4238333734532D52     US      USD       True
# 2  2020-11-27   et  IEX_5030314338392D52     US      USD       True
# 3  2020-11-27   et  IEX_474B433136332D52     US      USD       True
# 4  2020-11-27   ad  IEX_44595A4C53392D52     US      USD       True
# 5  2020-11-27   cs  IEX_5230483539302D52     US      USD       True
# 6  2020-11-27   ut  IEX_474656574E422D52     US      USD       True
# 7  2020-11-27   wt  IEX_5750544759342D52     US      USD       True
# 8  2020-11-27   et  IEX_5253355435362D52     US      USD       True
# 9  2020-11-27   cs  IEX_5351474631562D52     US      USD       True
#
#            figi      cik
# 0  263G0VB0CD0B  1127949
# 1  B3HD00GBT33B  1714421
# 2  80G0B45BSFPX     None
# 3  020GP8BLX7BX     None
# 4  B06SP0VBG302     None
# 5  KR048G0B7B7V     None
# 6  GP70HVKBPQB0     None
# 7  B040B0X7GSRY     None
# 8  R6YB0BDGWB00     None
# 9  1DBBB07300G3     None

# %%
for index, row in symbols.iterrows():
    print(row['symbol'])
# Out:
# A
# AA
# AAA
# AAAU
# AACG
# AACQ
# AACQU
# AACQW
# AADR
# AAIC

# %%
df = get_historical_data('AAPL', datetime.now() - relativedelta(days=60), datetime.now(), close_only=True, output_format='pandas', token=IEX_TOKEN)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): sandbox.iexapis.com:443
# DEBUG:urllib3.connectionpool:https://sandbox.iexapis.com:443 "GET /stable/stock/market/batch?symbols=AAPL&types=chart&range=3m&chartByDay=False&chartCloseOnly=True&token=Tpk_57fa15c2c86b4dadbb31e0c1ad1db895 HTTP/1.1" 200 None

# %%
df.dtypes
# Out:
# close     float64
# volume     object
# dtype: object

# %%
df["close"] = pd.to_numeric(df["close"])
df["volume"] = pd.to_numeric(df["volume"])
df
# Out:
#                 close     volume
# 2020-09-29  103474050  103474050
# 2020-09-30  148670913  148670913
# 2020-10-01  120719961  120719961
# 2020-10-02  151018262  151018262
# 2020-10-05  106920371  106920371
# 2020-10-06  165191057  165191057
# 2020-10-07   99431256   99431256
# 2020-10-08   87377765   87377765
# 2020-10-09  103237292  103237292
# 2020-10-12  241032789  241032789
# 2020-10-13  264518555  264518555
# 2020-10-14  151287209  151287209
# 2020-10-15  116441016  116441016
# 2020-10-16  117803417  117803417
# 2020-10-19  126225078  126225078
# 2020-10-20  128409275  128409275
# 2020-10-21   91958885   91958885
# 2020-10-22  102046503  102046503
# 2020-10-23   84475288   84475288
# 2020-10-26  111961900  111961900
# 2020-10-27   92396926   92396926
# 2020-10-28  145395475  145395475
# 2020-10-29  150044859  150044859
# 2020-10-30  192647476  192647476
# 2020-11-02  127678146  127678146
# 2020-11-03  112082802  112082802
# 2020-11-04  140266027  140266027
# 2020-11-05  129552860  129552860
# 2020-11-06  118255410  118255410
# 2020-11-09  161644064  161644064
# 2020-11-10  139651162  139651162
# 2020-11-11  113000038  113000038
# 2020-11-12  103928559  103928559
# 2020-11-13   85686623   85686623
# 2020-11-16   92968259   92968259
# 2020-11-17   77828184   77828184
# 2020-11-18   76886055   76886055
# 2020-11-19   77653420   77653420
# 2020-11-20   76614689   76614689
# 2020-11-23  133275775  133275775
# 2020-11-24  115865679  115865679
# 2020-11-25   76907454   76907454
