# %%
# %load_ext autoreload
# %autoreload 2

# %%
from iexfinance.refdata import get_symbols, get_iex_symbols
import os
import pandas as pd
from datetime import datetime, date
from iexfinance.stocks import get_historical_data
from dateutil.relativedelta import relativedelta

# %%
# Used to log the `MESSAGES USED` in `_IEXBAse`.
# https://addisonlynch.github.io/iexfinance/stable/logging.html
import logging
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)
logging.debug("test")
os.environ["IEX_LOG_LEVEL"] = "DEBUG"
# Out:
# DEBUG:root:test

# %%
IEX_TOKEN = "Tpk_57fa15c2c86b4dadbb31e0c1ad1db895"
os.environ["IEX_API_VERSION"] = "iexcloud-sandbox"

# %%
symbols = get_symbols(token=IEX_TOKEN)[0:10]
symbols
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): sandbox.iexapis.com:443
# DEBUG:urllib3.connectionpool:https://sandbox.iexapis.com:443 "GET /stable/ref-data/symbols?token=Tpk_57fa15c2c86b4dadbb31e0c1ad1db895 HTTP/1.1" 200 None
#   symbol exchange exchangeSuffix                     exchangeName        date  \
# 0  ALTG+      SYN             UN    ,OI .ANTXGE HNKNR C YCWKCOEES  2020-11-29
# 1   CMLS      SAN              0       GENN/BS(R)TOAAAAMM SDLQLK   2020-11-29
# 2   IAGG   BUSATS             UF  BZCEENEEIG.OUAB XXS  CS IUHQ.ET  2020-11-29
# 3  AMH-E      NYS             UN    KC WNG OYAX NNCKCRTSE,.IOHEE   2020-11-29
# 4   MAGS      ANS              0       G (AALDASQTESAKMRNB ONM/L)  2020-11-29
# 5  GRX-B      YSN             NU    HNY CK,.GWRO NAOKST  INEXCCEE  2020-11-29
# 6   AUGZ   BSTAUS             FU  AENXUBGSC EES .Z BC OTQUEIXHEI.  2020-11-29
# 7    HYB      YNS             NU    KEK WRNNSCNT.COEGI X ,AY OCEH  2020-11-29
# 8   AQNA      SYN             UN     NR KCA HEXEGC ON.SEYTC,KONWI  2020-11-29
# 9   CURO      YNS             NU    EKRIONNWE CHCKY  EN.C OATSXG,  2020-11-29
#
#   type iexId region currency  isEnabled          figi      cik  \
# 0   wt  None     US      USD       True  BL620BRNGKZ0  1798544
# 1   cs  None     US      USD       True  LG02XBX0MB83  1092148
# 2   et  None     US      USD       True  0VSB0GPDB1B2   925627
# 3   ps  None     US      USD       True          None  1621291
# 4   cs  None     US      USD       True  3LQB00SBG0BD   899764
# 5   ps  None     US      USD       True          None  1439446
# 6   et  None     US      USD       True  GZGBB0FWDF30  1745814
# 7   cs  None     US      USD       True  B0PML50T0BBG   829330
# 8   ps  None     US      USD       True          None  1207638
# 9   cs  None     US      USD       True  40B404BGG3P5  1756426
#
#                     lei
# 0                  None
# 1  C5S41AK085NW0Y9VO3SU
# 2  D5IH34P00095D7G9Y6BE
# 3  U0047W385PA50OJU4Z9N
# 4                  None
# 5  Z0HF245983WL3G0LNXUT
# 6                  None
# 7                  None
# 8  3XQKVLJ5UI570947XT50
# 9  44K39KC7YE0G205708HJ

# %%
for index, row in symbols.iterrows():
    print(row['symbol'])
# Out:
# ALTG+
# CMLS
# IAGG
# AMH-E
# MAGS
# GRX-B
# AUGZ
# HYB
# AQNA
# CURO

# %%
df = get_historical_data('AAPL', datetime.now() - relativedelta(days=60), datetime.now(), close_only=True, output_format='pandas', token=IEX_TOKEN)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): sandbox.iexapis.com:443
# DEBUG:urllib3.connectionpool:https://sandbox.iexapis.com:443 "GET /stable/stock/market/batch?symbols=AAPL&types=chart&range=3m&chartByDay=False&chartCloseOnly=True&token=Tpk_57fa15c2c86b4dadbb31e0c1ad1db895 HTTP/1.1" 200 None
# OOOOLSHANSKY 2020-09-30 20:02:48.550064 2020-11-29 20:02:48.550125

# %%
df.dtypes
# Out:
# close     object
# volume    object
# dtype: object

# %%
df["close"] = pd.to_numeric(df["close"])
df["volume"] = pd.to_numeric(df["volume"])
df
# Out:
#              close     volume
# 2020-10-01  117.82  117162637
# 2020-10-02  118.52  146427041
# 2020-10-05  118.70  106813591
# 2020-10-06  118.68  167267129
# 2020-10-07  120.78   99151890
# 2020-10-08  118.98   87558059
# 2020-10-09  120.48  102044149
# 2020-10-12  126.30  244203571
# 2020-10-13  122.70  267991102
# 2020-10-14  123.48  153585188
# 2020-10-15  122.38  116058506
# 2020-10-16  121.63  115842137
# 2020-10-19  120.55  125455900
# 2020-10-20  118.08  125224823
# 2020-10-21  118.71   93211736
# 2020-10-22  117.76  104323968
# 2020-10-23  117.59   84297542
# 2020-10-26  119.85  115380327
# 2020-10-27  118.60   93095492
# 2020-10-28  111.40  148055644
# 2020-10-29  118.22  152067806
# 2020-10-30  112.76  193371415
# 2020-11-02  112.57  126920853
# 2020-11-03  115.05  112413770
# 2020-11-04  115.02  140180570
# 2020-11-05  124.97  129428955
# 2020-11-06  122.92  119269128
# 2020-11-09  121.74  161271166
# 2020-11-10  119.04  140136333
# 2020-11-11  120.03  113214191
# 2020-11-12  121.11  105138966
# 2020-11-13  122.50   84929914
# 2020-11-16  121.60   94641411
# 2020-11-17  121.20   75853056
# 2020-11-19  121.76   75570917
# 2020-11-20  121.76   76591841
# 2020-11-23  118.89  131338093
# 2020-11-24  117.14  117245921
# 2020-11-25  117.99   79205415
# 2020-11-27  118.07   48595243

# %%
start = datetime.now() - relativedelta(days=60)
end = datetime.now()
symbols = ['AAPL', 'GOOG']
json = get_historical_data(symbols, start, end, close_only=False, output_format='json', token=IEX_TOKEN)
df = get_historical_data(symbols, start, end, close_only=False, output_format='pandas', token=IEX_TOKEN)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): sandbox.iexapis.com:443
# DEBUG:urllib3.connectionpool:https://sandbox.iexapis.com:443 "GET /stable/stock/market/batch?symbols=AAPL%2CGOOG&types=chart&range=3m&chartByDay=False&chartCloseOnly=False&token=Tpk_57fa15c2c86b4dadbb31e0c1ad1db895 HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): sandbox.iexapis.com:443
# OOOOLSHANSKY 2020-09-30 20:02:48.913843 2020-11-29 20:02:48.913935
# DEBUG:urllib3.connectionpool:https://sandbox.iexapis.com:443 "GET /stable/stock/market/batch?symbols=AAPL%2CGOOG&types=chart&range=3m&chartByDay=False&chartCloseOnly=False&token=Tpk_57fa15c2c86b4dadbb31e0c1ad1db895 HTTP/1.1" 200 None
# OOOOLSHANSKY 2020-09-30 20:02:48.913843 2020-11-29 20:02:48.913935

# %%
json['AAPL']['chart']
# Out:
# [{'close': 132.55,
#   'fclose': 132.9313,
#   'fhigh': 135.9613,
#   'flow': 131.178,
#   'fopen': 129.9244,
#   'fvolume': 226490219,
#   'high': 132,
#   'low': 127,
#   'open': 130.59,
#   'symbol': 'AAPL',
#   'uclose': 132.52,
#   'uhigh': 137,
#   'ulow': 129,
#   'uopen': 133.31,
#   'uvolume': 227115203,
#   'volume': 232773641,
#   'id': 'CCRPHETSIAOI_LRSI',
#   'key': 'ALAP',
#   'subkey': '0',
#   'date': '2020-08-31',
#   'updated': 1613817524796,
#   'changeOverTime': 0,
#   'marketChangeOverTime': 0,
#   'label': 'Aug 31, 20',
#   'change': 0},
#  {'close': 136.54,
#   'fclose': 134.0485,
#   'fhigh': 136.5067,
#   'flow': 134.1534,
#   'fopen': 135.1618,
#   'fvolume': 157913249,
#   'high': 134.9,
#   'low': 134.5,
#   'open': 133.1,
#   'symbol': 'AAPL',
#   'uclose': 139.46,
#   'uhigh': 138.4,
#   'ulow': 137.01,
#   'uopen': 136.63,
#   'uvolume': 156459116,
#   'volume': 158697887,
#   'id': 'HRCPCI_TRIISSLAEO',
#   'key': 'LAPA',
#   'subkey': '0',
#   'date': '2020-09-01',
#   'updated': 1665790874040,
#   'changeOverTime': 0.04156554951252064,
#   'marketChangeOverTime': 0.04160944863247306,
#   'label': 'Sep 1, 20',
#   'change': 5.307850735846419},
#  {'close': 134.2,
#   'fclose': 131.6427,
#   'fhigh': 143.9249,
#   'flow': 128.6582,
#   'fopen': 138.562,
#   'fvolume': 204087903,
#   'high': 139.6,
#   'low': 129,
#   'open': 140.79,
#   'symbol': 'AAPL',
#   'uclose': 132.7,
#   'uhigh': 141.16,
#   'ulow': 128,
#   'uopen': 143.18,
#   'uvolume': 204199250,
#   'volume': 203248801,
#   'id': 'TLPRCICA_IORHEISS',
#   'key': 'AALP',
#   'subkey': '0',
#   'date': '2020-09-02',
#   'updated': 1613453802294,
#   'changeOverTime': 0.018433522290617413,
#   'marketChangeOverTime': 0.01841439736145255,
#   'label': 'Sep 2, 20',
#   'change': -2.79561963234101},
#  {'close': 123.66,
#   'fclose': 124.2903,
#   'fhigh': 130.0711,
#   'flow': 121.0501,
#   'fopen': 132.9471,
#   'fvolume': 265738281,
#   'high': 134.77,
#   'low': 121.2,
#   'open': 128.17,
#   'symbol': 'AAPL',
#   'uclose': 124.97,
#   'uhigh': 130.99,
#   'ulow': 125.5,
#   'uopen': 128.48,
#   'uvolume': 257743233,
#   'volume': 260799973,
#   'id': 'ROIITHSRCC_IALSEP',
#   'key': 'ALPA',
#   'subkey': '0',
#   'date': '2020-09-03',
#   'updated': 1615860088347,
#   'changeOverTime': -0.0660532686195184,
#   'marketChangeOverTime': -0.06442503141726337,
#   'label': 'Sep 3, 20',
#   'change': -10.60197428349802},
#  {'close': 124.75,
#   'fclose': 120.7939,
#   'fhigh': 126.248,
#   'flow': 113.428,
#   'fopen': 120.995,
#   'fvolume': 334046616,
#   'high': 125.2,
#   'low': 111.52,
#   'open': 120.85,
#   'symbol': 'AAPL',
#   'uclose': 121.99,
#   'uhigh': 124.5,
#   'ulow': 113.58,
#   'uopen': 123.79,
#   'uvolume': 338941684,
#   'volume': 334026973,
#   'id': 'I_CIRPCSOTARHESLI',
#   'key': 'PAAL',
#   'subkey': '0',
#   'date': '2020-09-04',
#   'updated': 1658625684030,
#   'changeOverTime': -0.06263373625909255,
#   'marketChangeOverTime': -0.06516348410268492,
#   'label': 'Sep 4, 20',
#   'change': 0.0819384935744319},
#  {'close': 114.87,
#   'fclose': 115.0886,
#   'fhigh': 122.8921,
#   'flow': 116.5733,
#   'fopen': 119.2024,
#   'fvolume': 242089017,
#   'high': 119.43,
#   'low': 114.98,
#   'open': 116.13,
#   'symbol': 'AAPL',
#   'uclose': 116.09,
#   'uhigh': 122.44,
#   'ulow': 117.55,
#   'uopen': 117.6,
#   'uvolume': 241425506,
#   'volume': 239223100,
#   'id': 'CSIRAI_IEPSORHTCL',
#   'key': 'AAPL',
#   'subkey': '0',
#   'date': '2020-09-08',
#   'updated': 1637315631023,
#   'changeOverTime': -0.13010557987158788,
#   'marketChangeOverTime': -0.12880330194093384,
#   'label': 'Sep 8, 20',
#   'change': -8.38},
#  {'close': 118.08,
#   'fclose': 121.0378,
#   'fhigh': 119.9969,
#   'flow': 117.0366,
#   'fopen': 120.409,
#   'fvolume': 177445812,
#   'high': 120.55,
#   'low': 119.41,
#   'open': 122,
#   'symbol': 'AAPL',
#   'uclose': 122.84,
#   'uhigh': 124.78,
#   'ulow': 116.44,
#   'uopen': 119.44,
#   'uvolume': 182414320,
#   'volume': 178905991,
#   'id': 'I_CIOAHSILTCRERSP',
#   'key': 'PALA',
#   'subkey': '0',
#   'date': '2020-09-09',
#   'updated': 1665386807874,
#   'changeOverTime': -0.09380717810569766,
#   'marketChangeOverTime': -0.09430026329407405,
#   'label': 'Sep 9, 20',
#   'change': 4.7},
#  {'close': 118.34,
#   'fclose': 115.1835,
#   'fhigh': 121.7627,
#   'flow': 116.5744,
#   'fopen': 120.3129,
#   'fvolume': 187483864,
#   'high': 120.9,
#   'low': 115.7,
#   'open': 122.81,
#   'symbol': 'AAPL',
#   'uclose': 114.52,
#   'uhigh': 121.6,
#   'ulow': 114.2,
#   'uopen': 125.31,
#   'uvolume': 187271809,
#   'volume': 184836613,
#   'id': 'ATLRCCROSIEIH_ISP',
#   'key': 'AAPL',
#   'subkey': '0',
#   'date': '2020-09-10',
#   'updated': 1655336156825,
#   'changeOverTime': -0.12222892108165348,
#   'marketChangeOverTime': -0.12410357685704981,
#   'label': 'Sep 10, 20',
#   'change': -3.9655108645617534},
#  {'close': 115,
#   'fclose': 117.3043,
#   'fhigh': 115.3552,
#   'flow': 113.9758,
#   'fopen': 118.1647,
#   'fvolume': 186687580,
#   'high': 117.55,
#   'low': 114,
#   'open': 116.66,
#   'symbol': 'AAPL',
#   'uclose': 114,
#   'uhigh': 117.79,
#   'ulow': 114,
#   'uopen': 116.8,
#   'uvolume': 180921237,
#   'volume': 186773841,
#   'id': 'ELTRRACCH_ISSPIOI',
#   'key': 'PAAL',
#   'subkey': '0',
#   'date': '2020-09-11',
#   'updated': 1660755191010,
#   'changeOverTime': -0.13575755280069587,
#   'marketChangeOverTime': -0.13513966240492845,
#   'label': 'Sep 11, 20',
#   'change': -1.5006160476972281},
#  {'close': 118.262,
#   'fclose': 116.1336,
#   'fhigh': 117.3693,
#   'flow': 116.0337,
#   'fopen': 114.5964,
#   'fvolume': 144960297,
#   'high': 121.19,
#   'low': 113,
#   'open': 115.53,
#   'symbol': 'AAPL',
#   'uclose': 118.82,
#   'uhigh': 120.02,
#   'ulow': 114.9,
#   'uopen': 115.25,
#   'uvolume': 145223773,
#   'volume': 146687706,
#   'id': 'ASLITRHIIRCPO_CSE',
#   'key': 'LPAA',
#   'subkey': '0',
#   'date': '2020-09-14',
#   'updated': 1665555523098,
#   'changeOverTime': -0.10872206891353586,
#   'marketChangeOverTime': -0.10763671810823634,
#   'label': 'Sep 14, 20',
#   'change': 3.459830558257746},
#  {'close': 118.59,
#   'fclose': 119.076,
#   'fhigh': 124.4586,
#   'flow': 116.1171,
#   'fopen': 120.5827,
#   'fvolume': 188694192,
#   'high': 119.243,
#   'low': 114.72,
#   'open': 120.06,
#   'symbol': 'AAPL',
#   'uclose': 116.72,
#   'uhigh': 124.216,
#   'ulow': 118.92,
#   'uopen': 119.7,
#   'uvolume': 185807528,
#   'volume': 184944560,
#   'id': '_STESRCHPILCORIAI',
#   'key': 'AALP',
#   'subkey': '0',
#   'date': '2020-09-15',
#   'updated': 1626785149405,
#   'changeOverTime': -0.1049126298745867,
#   'marketChangeOverTime': -0.1049845197567305,
#   'label': 'Sep 15, 20',
#   'change': 0.1939697588828861},
#  {'close': 112.67,
#   'fclose': 116.7837,
#   'fhigh': 120.3692,
#   'flow': 114.572,
#   'fopen': 119.4982,
#   'fvolume': 159249238,
#   'high': 117,
#   'low': 113.29,
#   'open': 116.9,
#   'symbol': 'AAPL',
#   'uclose': 114.52,
#   'uhigh': 121,
#   'ulow': 115.56,
#   'uopen': 120.67,
#   'uvolume': 156127740,
#   'volume': 155069267,
#   'id': 'PRI_CTSIRHIEACSOL',
#   'key': 'APAL',
#   'subkey': '0',
#   'date': '2020-09-16',
#   'updated': 1629469721193,
#   'changeOverTime': -0.1311035908397835,
#   'marketChangeOverTime': -0.13222021326528516,
#   'label': 'Sep 16, 20',
#   'change': -3.575204229492077},
#  {'close': 111.33,
#   'fclose': 115.3,
#   'fhigh': 117.5009,
#   'flow': 112.8724,
#   'fopen': 113.685,
#   'fvolume': 181809835,
#   'high': 115.4,
#   'low': 109.81,
#   'open': 113.96,
#   'symbol': 'AAPL',
#   'uclose': 110.99,
#   'uhigh': 115.8,
#   'ulow': 109.09,
#   'uopen': 113.61,
#   'uvolume': 186477509,
#   'volume': 181176579,
#   'id': 'AIERLIICSROC_PTHS',
#   'key': 'APLA',
#   'subkey': '0',
#   'date': '2020-09-17',
#   'updated': 1634891754794,
#   'changeOverTime': -0.1459825531658011,
#   'marketChangeOverTime': -0.1464674797280357,
#   'label': 'Sep 17, 20',
#   'change': -1.860694379088804},
#  {'close': 112.07,
#   'fclose': 108.478,
#   'fhigh': 114.32,
#   'flow': 109.486,
#   'fopen': 113.5685,
#   'fvolume': 300184850,
#   'high': 114.29,
#   'low': 107.83,
#   'open': 111.4,
#   'symbol': 'AAPL',
#   'uclose': 110.6,
#   'uhigh': 112.31,
#   'ulow': 109.08,
#   'uopen': 112.7,
#   'uvolume': 294657545,
#   'volume': 300312488,
#   'id': '_CITIRORSEPSLIHCA',
#   'key': 'AALP',
#   'subkey': '0',
#   'date': '2020-09-18',
#   'updated': 1680106920987,
#   'changeOverTime': -0.1724778802824452,
#   'marketChangeOverTime': -0.17955701767901983,
#   'label': 'Sep 18, 20',
#   'change': -3.7},
#  {'close': 110.26,
#   'fclose': 112.4033,
#   'fhigh': 110.1085,
#   'flow': 105.9511,
#   'fopen': 107.27,
#   'fvolume': 205056868,
#   'high': 111.84,
#   'low': 107.6,
#   'open': 109.01,
#   'symbol': 'AAPL',
#   'uclose': 113.23,
#   'uhigh': 111.64,
#   'ulow': 107.8,
#   'uopen': 105.42,
#   'uvolume': 200369841,
#   'volume': 202089223,
#   'id': 'IPRS_ITCLACOSHREI',
#   'key': 'AALP',
#   'subkey': '0',
#   'date': '2020-09-21',
#   'updated': 1619003948571,
#   'changeOverTime': -0.14885645271773557,
#   'marketChangeOverTime': -0.1480627754952663,
#   'label': 'Sep 21, 20',
#   'change': 3.350550319710798},
#  {'close': 116.78,
#   'fclose': 112.1331,
#   'fhigh': 115.9359,
#   'flow': 113.871,
#   'fopen': 113.1889,
#   'fvolume': 186251820,
#   'high': 113.01,
#   'low': 111.4,
#   'open': 113.31,
#   'symbol': 'AAPL',
#   'uclose': 114.13,
#   'uhigh': 116.4,
#   'ulow': 114.26,
#   'uopen': 116.58,
#   'uvolume': 189418826,
#   'volume': 189493129,
#   'id': 'EC_SLCIPRITIORHSA',
#   'key': 'APLA',
#   'subkey': '0',
#   'date': '2020-09-22',
#   'updated': 1652110608855,
#   'changeOverTime': -0.1384268090938598,
#   'marketChangeOverTime': -0.1397198135373801,
#   'label': 'Sep 22, 20',
#   'change': 1.806778402777053},
#  {'close': 112.03,
#   'fclose': 111.4679,
#   'fhigh': 113.2819,
#   'flow': 108.9684,
#   'fopen': 113.3102,
#   'fvolume': 152136477,
#   'high': 112.36,
#   'low': 106.83,
#   'open': 113.52,
#   'symbol': 'AAPL',
#   'uclose': 107.6,
#   'uhigh': 113.45,
#   'ulow': 110.52,
#   'uopen': 116.99,
#   'uvolume': 156584442,
#   'volume': 154671867,
#   'id': 'HRTASORCCIE_SPLII',
#   'key': 'LAPA',
#   'subkey': '0',
#   'date': '2020-09-23',
#   'updated': 1683208417683,
#   'changeOverTime': -0.1720358912535357,
#   'marketChangeOverTime': -0.17150640089699135,
#   'label': 'Sep 23, 20',
#   'change': -4.742790440265979},
#  {'close': 111.22,
#   'fclose': 109.3048,
#   'fhigh': 113.0591,
#   'flow': 105.3589,
#   'fopen': 108.756,
#   'fvolume': 167826388,
#   'high': 115.54,
#   'low': 106,
#   'open': 106.4,
#   'symbol': 'AAPL',
#   'uclose': 111.49,
#   'uhigh': 115.14,
#   'ulow': 106,
#   'uopen': 106.34,
#   'uvolume': 170133995,
#   'volume': 171659399,
#   'id': 'S_HARSICLROCIPEIT',
#   'key': 'PALA',
#   'subkey': '0',
#   'date': '2020-09-24',
#   'updated': 1647021335084,
#   'changeOverTime': -0.1671644801047278,
#   'marketChangeOverTime': -0.1637812910878322,
#   'label': 'Sep 24, 20',
#   'change': 1.1408774413165876},
#  {'close': 115.76,
#   'fclose': 115.4824,
#   'fhigh': 116.3473,
#   'flow': 108.3628,
#   'fopen': 110.4016,
#   'fvolume': 151123784,
#   'high': 114.1,
#   'low': 110.05,
#   'open': 112.86,
#   'symbol': 'AAPL',
#   'uclose': 116.55,
#   'uhigh': 114.61,
#   'ulow': 109.17,
#   'uopen': 112.98,
#   'uvolume': 150280327,
#   'volume': 153877477,
#   'id': 'TERICIOI_PAHRCLSS',
#   'key': 'AALP',
#   'subkey': '0',
#   'date': '2020-09-25',
#   'updated': 1634804157096,
#   'changeOverTime': -0.1351104518386705,
#   'marketChangeOverTime': -0.1345310020997501,
#   'label': 'Sep 25, 20',
#   'change': 4.146408815520968},
#  {'close': 116.02,
#   'fclose': 116.994,
#   'fhigh': 116.6512,
#   'flow': 115.5273,
#   'fopen': 116.3207,
#   'fvolume': 142786488,
#   'high': 116.65,
#   'low': 117.4,
#   'open': 119.15,
#   'symbol': 'AAPL',
#   'uclose': 115.81,
#   'uhigh': 120.02,
#   'ulow': 116.23,
#   'uopen': 118.87,
#   'uvolume': 141000458,
#   'volume': 139276676,
#   'id': 'EPLAIOSCCRTR_ISHI',
#   'key': 'APAL',
#   'subkey': '0',
#   'date': '2020-09-28',
#   'updated': 1680038714522,
#   'changeOverTime': -0.11401758733981819,
#   'marketChangeOverTime': -0.11006355862179039,
#   'label': 'Sep 28, 20',
#   'change': 2.7524245181011993},
#  {'close': 119.28,
#   'fclose': 115.573,
#   'fhigh': 119.1948,
#   'flow': 115.2415,
#   'fopen': 117.0449,
#   'fvolume': 100567337,
#   'high': 119.97,
#   'low': 115.75,
#   'open': 115.79,
#   'symbol': 'AAPL',
#   'uclose': 119.6,
#   'uhigh': 116.48,
#   'ulow': 115.72,
#   'uopen': 118.92,
#   'uvolume': 101608614,
#   'volume': 100379443,
#   'id': 'RIAEITIOHS_SPCCRL',
#   'key': 'APLA',
#   'subkey': '0',
#   'date': '2020-09-29',
#   'updated': 1651112803304,
#   'changeOverTime': -0.1183095956978243,
#   'marketChangeOverTime': -0.119565800400901,
#   'label': 'Sep 29, 20',
#   'change': -0.896763858549273},
#  {'close': 117.26,
#   'fclose': 120.5339,
#   'fhigh': 118.535,
#   'flow': 114.0782,
#   'fopen': 118.843,
#   'fvolume': 146815265,
#   'high': 118.91,
#   'low': 114.24,
#   'open': 118.97,
#   'symbol': 'AAPL',
#   'uclose': 119.88,
#   'uhigh': 122.92,
#   'ulow': 113.64,
#   'uopen': 117.89,
#   'uvolume': 146933513,
#   'volume': 143633870,
#   'id': 'SAOCREPISH_ITRCIL',
#   'key': 'PAAL',
#   'subkey': '0',
#   'date': '2020-09-30',
#   'updated': 1619521848869,
#   'changeOverTime': -0.10548209797985812,
#   'marketChangeOverTime': -0.10599861397092765,
#   'label': 'Sep 30, 20',
#   'change': 1.7561117263704942},
#  {'close': 118.85,
#   'fclose': 122.1181,
#   'fhigh': 121.7763,
#   'flow': 119.7038,
#   'fopen': 119.7112,
#   'fvolume': 119927784,
#   'high': 121.43,
#   'low': 119.34,
#   'open': 119.01,
#   'symbol': 'AAPL',
#   'uclose': 120.2,
#   'uhigh': 121.23,
#   'ulow': 116.58,
#   'uopen': 123.4,
#   'uvolume': 119787125,
#   'volume': 117863570,
#   'id': 'IESPCCLHR_IAOISTR',
#   'key': 'AAPL',
#   'subkey': '0',
#   'date': '2020-10-01',
#   'updated': 1657367821678,
#   'changeOverTime': -0.09885817799952448,
#   'marketChangeOverTime': -0.09807488954336269,
#   'label': 'Oct 1, 20',
#   'change': 0.995446639564258},
#  {'close': 113.5,
#   'fclose': 113.3563,
#   'fhigh': 117.4907,
#   'flow': 114.9418,
#   'fopen': 113.5284,
#   'fvolume': 150988503,
#   'high': 116.9,
#   'low': 114.41,
#   'open': 114.3,
#   'symbol': 'AAPL',
#   'uclose': 118.37,
#   'uhigh': 120.31,
#   'ulow': 114.19,
#   'uopen': 115.72,
#   'uvolume': 151580156,
#   'volume': 147795286,
#   'id': 'HIOCTLEARRISC_PIS',
#   'key': 'ALPA',
#   'subkey': '0',
#   'date': '2020-10-02',
#   'updated': 1609776141353,
#   'changeOverTime': -0.1262031971555146,
#   'marketChangeOverTime': -0.12648924279720983,
#   'label': 'Oct 2, 20',
#   'change': -3.7729544399493546},
#  {'close': 120.4,
#   'fclose': 119.1253,
#   'fhigh': 120.1769,
#   'flow': 114.5977,
#   'fopen': 117.1823,
#   'fvolume': 109077520,
#   'high': 119.89,
#   'low': 113.84,
#   'open': 118.04,
#   'symbol': 'AAPL',
#   'uclose': 116.8,
#   'uhigh': 118.34,
#   'ulow': 114.18,
#   'uopen': 114.86,
#   'uvolume': 111292924,
#   'volume': 106493112,
#   'id': 'IRTIESRSHI_LAPCCO',
#   'key': 'LAAP',
#   'subkey': '0',
#   'date': '2020-10-05',
#   'updated': 1621150615937,
#   'changeOverTime': -0.09878070851215902,
#   'marketChangeOverTime': -0.09751399975536908,
#   'label': 'Oct 5, 20',
#   'change': 3.594298491205596},
#  {'close': 115.95,
#   'fclose': 117.5329,
#   'fhigh': 116.42,
#   'flow': 117.1743,
#   'fopen': 115.5039,
#   'fvolume': 166276167,
#   'high': 121.35,
#   'low': 114.73,
#   'open': 117.1,
#   'symbol': 'AAPL',
#   'uclose': 115.64,
#   'uhigh': 119.11,
#   'ulow': 112.74,
#   'uopen': 120.4,
#   'uvolume': 166509237,
#   'volume': 166354275,
#   'id': '_HERPLRSTOCIASIIC',
#   'key': 'PAAL',
#   'subkey': '0',
#   'date': '2020-10-06',
#   'updated': 1665448371511,
#   'changeOverTime': -0.12660656428525616,
#   'marketChangeOverTime': -0.12921316424965026,
#   'label': 'Oct 6, 20',
#   'change': -3.4268110887211796},
#  {'close': 116.88,
#   'fclose': 115.5261,
#   'fhigh': 119.474,
#   'flow': 115.1618,
#   'fopen': 119.2897,
#   'fvolume': 98119280,
#   'high': 117.32,
#   'low': 115.08,
#   'open': 114.76,
#   'symbol': 'AAPL',
#   'uclose': 115.16,
#   'uhigh': 118.18,
#   'ulow': 118.68,
#   'uopen': 117.07,
#   'uvolume': 97489393,
#   'volume': 97640934,
#   'id': 'C_POLREHRIIICTSAS',
#   'key': 'PAAL',
#   'subkey': '0',
#   'date': '2020-10-07',
#   'updated': 1638772451694,
#   'changeOverTime': -0.1101899208330798,
#   'marketChangeOverTime': -0.1118061071685968,
#   'label': 'Oct 7, 20',
#   'change': 2.011110443447921},
#  {'close': 120.07,
#   'fclose': 117.676,
#   'fhigh': 121.053,
#   'flow': 116.747,
#   'fopen': 117.3645,
#   'fvolume': 84552441,
#   'high': 120.3,
#   'low': 116.8299,
#   'open': 117.43,
#   'symbol': 'AAPL',
#   'uclose': 116.69,
#   'uhigh': 122.1,
#   'ulow': 117.7874,
#   'uopen': 116.38,
#   'uvolume': 85705846,
#   'volume': 85202520,
#   'id': '_IISELIPRTRCCOSAH',
#   'key': 'LPAA',
#   'subkey': '0',
#   'date': '2020-10-08',
#   'updated': 1681174735583,
#   'changeOverTime': -0.1104224301406805,
#   'marketChangeOverTime': -0.1093731016516556,
#   'label': 'Oct 8, 20',
#   'change': -0.11335040975585439},
#  {'close': 120,
#   'fclose': 121.1708,
#   'fhigh': 116.9003,
#   'flow': 114.8676,
#   'fopen': 120.5724,
#   'fvolume': 102410815,
#   'high': 122,
#   'low': 120.5,
#   'open': 116.62,
#   'symbol': 'AAPL',
#   'uclose': 121.07,
#   'uhigh': 118,
#   'ulow': 115.66,
#   'uopen': 120.37,
#   'uvolume': 101008676,
#   'volume': 103231158,
#   'id': 'LSEIRACSHOCT_PRII',
#   'key': 'PAAL',
#   'subkey': '0',
#   'date': '2020-10-09',
#   'updated': 1655663021793,
#   'changeOverTime': -0.09385499736569534,
#   'marketChangeOverTime': -0.09638107732542293,
#   'label': 'Oct 9, 20',
#   'change': 2},
#  {'close': 126.1,
#   'fclose': 127.2531,
#   'fhigh': 125.2291,
#   'flow': 119.1754,
#   'fopen': 125.4599,
#   'fvolume': 243642139,
#   'high': 127.89,
#   'low': 123.6462,
#   'open': 122.63,
#   'symbol': 'AAPL',
#   'uclose': 125,
#   'uhigh': 127.25,
#   'ulow': 124.2953,
#   'uopen': 123.73,
#   'uvolume': 246517622,
#   'volume': 248545197,
#   'id': 'SCIPT_ICSEIALORHR',
#   'key': 'ALAP',
#   'subkey': '0',
#   'date': '2020-10-12',
#   'updated': 1648548038733,
#   'changeOverTime': -0.037209667801355,
#   'marketChangeOverTime': -0.03713222369861293,
#   'label': 'Oct 12, 20',
#   'change': 7.772877041901823},
#  {'close': 122.7,
#   'fclose': 124.3723,
#   'fhigh': 129.721,
#   'flow': 124.8125,
#   'fopen': 130.775,
#   'fvolume': 263280936,
#   'high': 130.64,
#   'low': 120.23,
#   'open': 127.18,
#   'symbol': 'AAPL',
#   'uclose': 122.8,
#   'uhigh': 129.6,
#   'ulow': 120.21,
#   'uopen': 128.59,
#   'uvolume': 271844440,
#   'volume': 265920189,
#   'id': 'H_SEPTCLIAORICRSI',
#   'key': 'PLAA',
#   'subkey': '0',
#   'date': '2020-10-13',
#   'updated': 1665030324273,
#   'changeOverTime': -0.06333017190826125,
#   'marketChangeOverTime': -0.06251218695225304,
#   'label': 'Oct 13, 20',
#   'change': -3.4219535712009606},
#  {'close': 121.54,
#   'fclose': 122.6811,
#   'fhigh': 126.7673,
#   'flow': 125.373,
#   'fopen': 124.7904,
#   'fvolume': 151399902,
#   'high': 123.98,
#   'low': 120.02,
#   'open': 122,
#   'symbol': 'AAPL',
#   'uclose': 125.15,
#   'uhigh': 128.07,
#   'ulow': 123.3,
#   'uopen': 125,
#   'uvolume': 155416560,
#   'volume': 152645028,
#   'id': 'ICHSLII_ORTACPRES',
#   'key': 'ALPA',
#   'subkey': '0',
#   'date': '2020-10-14',
#   'updated': 1662866954191,
#   'changeOverTime': -0.06171060060727623,
#   'marketChangeOverTime': -0.0608599974767418,
#   'label': 'Oct 14, 20',
#   'change': 0.09132782033809461},
#  {'close': 123.96,
#   'fclose': 121.4262,
#   'fhigh': 122.7542,
#   'flow': 118.0568,
#   'fopen': 122.9851,
#   'fvolume': 116899846,
#   'high': 126.7,
#   'low': 118.35,
#   'open': 120.78,
#   'symbol': 'AAPL',
#   'uclose': 123.2,
#   'uhigh': 126.6,
#   'ulow': 121.63,
#   'uopen': 122.18,
#   'uvolume': 112754993,
#   'volume': 116251941,
#   'id': 'RCALIHTSSE_IRICOP',
#   'key': 'PLAA',
#   'subkey': '0',
#   'date': '2020-10-15',
#   'updated': 1617946268905,
#   'changeOverTime': -0.06540438123456299,
#   'marketChangeOverTime': -0.06559738711782775,
#   'label': 'Oct 15, 20',
#   'change': -0.487672205690974},
#  {'close': 122.28,
#   'fclose': 124.58,
#   'fhigh': 126.566,
#   'flow': 119.8479,
#   'fopen': 123.7953,
#   'fvolume': 120982704,
#   'high': 123.148,
#   'low': 120.86,
#   'open': 125.87,
#   'symbol': 'AAPL',
#   'uclose': 119.8,
#   'uhigh': 126.874,
#   'ulow': 123.36,
#   'uopen': 126.62,
#   'uvolume': 116371928,
#   'volume': 120014049,
#   'id': 'LHCIAIRICOPSSTE_R',
#   'key': 'APLA',
#   'subkey': '0',
#   'date': '2020-10-16',
#   'updated': 1654198101622,
#   'changeOverTime': -0.0805624352865286,
#   'marketChangeOverTime': -0.0808974555127457,
#   'label': 'Oct 16, 20',
#   'change': -1.6998378859054213},
#  {'close': 117.07,
#   'fclose': 117.7267,
#   'fhigh': 120.2971,
#   'flow': 120.8553,
#   'fopen': 121.7622,
#   'fvolume': 122276963,
#   'high': 125.499,
#   'low': 119.06,
#   'open': 123.53,
#   'symbol': 'AAPL',
#   'uclose': 120.8,
#   'uhigh': 124.758,
#   'ulow': 119.75,
#   'uopen': 120.4,
#   'uvolume': 122071760,
#   'volume': 125592554,
#   'id': 'SIH_CSOALIEPCITRR',
#   'key': 'AALP',
#   'subkey': '0',
#   'date': '2020-10-19',
#   'updated': 1675866896699,
#   'changeOverTime': -0.1026205217612357,
#   'marketChangeOverTime': -0.10412722101294272,
#   'label': 'Oct 19, 20',
#   'change': -3.160343458420381},
#  {'close': 121.7,
#   'fclose': 118.9464,
#   'fhigh': 123.4794,
#   'flow': 117.2462,
#   'fopen': 118.7124,
#   'fvolume': 130071866,
#   'high': 124.85,
#   'low': 116.19,
#   'open': 117.6,
#   'symbol': 'AAPL',
#   'uclose': 120.76,
#   'uhigh': 123.15,
#   'ulow': 120.04,
#   'uopen': 118,
#   'uvolume': 129517509,
#   'volume': 125831086,
#   'id': '_OILEACISTISRPCRH',
#   'key': 'LAAP',
#   'subkey': '0',
#   'date': '2020-10-20',
#   'updated': 1625298962966,
#   'changeOverTime': -0.09168628323712233,
#   'marketChangeOverTime': -0.09344918517395645,
#   'label': 'Oct 20, 20',
#   'change': 1.5615034956718008},
#  {'close': 121.38,
#   'fclose': 121.9835,
#   'fhigh': 122.7056,
#   'flow': 120.6675,
#   'fopen': 117.8171,
#   'fvolume': 91793092,
#   'high': 120.85,
#   'low': 118.34,
#   'open': 119.36,
#   'symbol': 'AAPL',
#   'uclose': 119.98,
#   'uhigh': 124.008,
#   'ulow': 119.83,
#   'uopen': 116.88,
#   'uvolume': 91810553,
#   'volume': 89975948,
#   'id': 'TOSI_ALCEPCRRISHI',
#   'key': 'PLAA',
#   'subkey': '0',
#   'date': '2020-10-21',
#   'updated': 1641062134117,
#   'changeOverTime': -0.09807025932041896,
#   'marketChangeOverTime': -0.09745707290059172,
#   'label': 'Oct 21, 20',
#   'change': -0.6693876821649722},
#  {'close': 120.04,
#   'fclose': 119.8282,
#   'fhigh': 120.3929,
#   'flow': 117.0943,
#   'fopen': 122.704,
#   'fvolume': 105888555,
#   'high': 120.8,
#   'low': 114.93,
#   'open': 120.38,
#   'symbol': 'AAPL',
#   'uclose': 121.17,
#   'uhigh': 118.14,
#   'ulow': 117.24,
#   'uopen': 122.64,
#   'uvolume': 102874747,
#   'volume': 104854907,
#   'id': 'OIIECRRPCS_LSTIHA',
#   'key': 'APAL',
#   'subkey': '0',
#   'date': '2020-10-22',
#   'updated': 1610631284724,
#   'changeOverTime': -0.1073762407880894,
#   'marketChangeOverTime': -0.1036291431938539,
#   'label': 'Oct 22, 20',
#   'change': -1.141303048678427},
#  {'close': 116.71,
#   'fclose': 118.1309,
#   'fhigh': 119.6972,
#   'flow': 119.5801,
#   'fopen': 119.2796,
#   'fvolume': 83447232,
#   'high': 116.92,
#   'low': 116.36,
#   'open': 121.31,
#   'symbol': 'AAPL',
#   'uclose': 118.98,
#   'uhigh': 118.67,
#   'ulow': 119.18,
#   'uopen': 121.91,
#   'uvolume': 82858685,
#   'volume': 86356448,
#   'id': 'IEORPCCHRAITSLIS_',
#   'key': 'LPAA',
#   'subkey': '0',
#   'date': '2020-10-23',
#   'updated': 1665116276797,
#   'changeOverTime': -0.1106025645658733,
#   'marketChangeOverTime': -0.11114242708971721,
#   'label': 'Oct 23, 20',
#   'change': -0.7428168251010975},
#  {'close': 115.39,
#   'fclose': 116.5071,
#   'fhigh': 116.4023,
#   'flow': 117.678,
#   'fopen': 117.4967,
#   'fvolume': 114429453,
#   'high': 122.3,
#   'low': 115.54,
#   'open': 114.07,
#   'symbol': 'AAPL',
#   'uclose': 118.54,
#   'uhigh': 118.95,
#   'ulow': 118.08,
#   'uopen': 117.04,
#   'uvolume': 112919910,
#   'volume': 112660941,
#   'id': 'ERLRSIISTHOAPCIC_',
#   'key': 'APLA',
#   'subkey': '0',
#   'date': '2020-10-26',
#   'updated': 1652031304314,
#   'changeOverTime': -0.11114866316776266,
#   'marketChangeOverTime': -0.10862110464262131,
#   'label': 'Oct 26, 20',
#   'change': 0.010320850501966551},
#  {'close': 119.3,
#   'fclose': 118.2099,
#   'fhigh': 118.065,
#   'flow': 118.7827,
#   'fopen': 117.6582,
#   'fvolume': 96243116,
#   'high': 119.5,
#   'low': 120.0985,
#   'open': 117.94,
#   'symbol': 'AAPL',
#   'uclose': 119.2,
#   'uhigh': 119.37,
#   'ulow': 120.1036,
#   'uopen': 120.41,
#   'uvolume': 95230243,
#   'volume': 94847620,
#   'id': 'SPLSIE_ATCCHROIRI',
#   'key': 'PALA',
#   'subkey': '0',
#   'date': '2020-10-27',
#   'updated': 1657453247620,
#   'changeOverTime': -0.09946941795896094,
#   'marketChangeOverTime': -0.09924303516421457,
#   'label': 'Oct 27, 20',
#   'change': 1.6003544842370534},
#  {'close': 116.3,
#   'fclose': 116.0731,
#   'fhigh': 119.7267,
#   'flow': 114.1698,
#   'fopen': 118.0827,
#   'fvolume': 144660773,
#   'high': 118.85,
#   'low': 111.1,
#   'open': 117.71,
#   'symbol': 'AAPL',
#   'uclose': 113.7,
#   'uhigh': 118.38,
#   'ulow': 116.2,
#   'uopen': 118.94,
#   'uvolume': 148295348,
#   'volume': 146465090,
#   'id': '_LSCHCOSIRIARITEP',
#   'key': 'PAAL',
#   'subkey': '0',
#   'date': '2020-10-28',
#   'updated': 1680538547665,
#   'changeOverTime': -0.14514538211548864,
#   'marketChangeOverTime': -0.1406739201395814,
#   'label': 'Oct 28, 20',
#   'change': -5.5754200745472655},
#  {'close': 116.28,
#   'fclose': 117.9613,
#   'fhigh': 119.2427,
#   'flow': 115.6556,
#   'fopen': 115.5229,
#   'fvolume': 151065206,
#   'high': 119.46,
#   'low': 112.8,
#   'open': 116.41,
#   'symbol': 'AAPL',
#   'uclose': 117.28,
#   'uhigh': 117.37,
#   'ulow': 114.4,
#   'uopen': 112.79,
#   'uvolume': 148413335,
#   'volume': 147818639,
#   'id': 'CILSHPACSETRRO_II',
#   'key': 'PAAL',
#   'subkey': '0',
#   'date': '2020-10-29',
#   'updated': 1641835501378,
#   'changeOverTime': -0.109838651021759,
#   'marketChangeOverTime': -0.10956522568318984,
#   'label': 'Oct 29, 20',
#   'change': 4.19379914680188},
#  {'close': 113.04,
#   'fclose': 111.4662,
#   'fhigh': 114.06,
#   'flow': 112.7547,
#   'fopen': 112.9359,
#   'fvolume': 198975024,
#   'high': 112.59,
#   'low': 110.19,
#   'open': 116.54,
#   'symbol': 'AAPL',
#   'uclose': 111.27,
#   'uhigh': 117.15,
#   'ulow': 108.56,
#   'uopen': 111.47,
#   'uvolume': 192986852,
#   'volume': 193650867,
#   'id': 'ROEIC_PLSAHSRITIC',
#   'key': 'AAPL',
#   'subkey': '0',
#   'date': '2020-10-30',
#   'updated': 1621975352282,
#   'changeOverTime': -0.15969905295645334,
#   'marketChangeOverTime': -0.15978305153646513,
#   'label': 'Oct 30, 20',
#   'change': -6.483849983247837},
#  {'close': 111.75,
#   'fclose': 113.3524,
#   'fhigh': 111.4316,
#   'flow': 107.5616,
#   'fopen': 111.5055,
#   'fvolume': 124580929,
#   'high': 115.07,
#   'low': 107.45,
#   'open': 109.39,
#   'symbol': 'AAPL',
#   'uclose': 112.58,
#   'uhigh': 111.83,
#   'ulow': 111.93,
#   'uopen': 110.31,
#   'uvolume': 122876925,
#   'volume': 126730464,
#   'id': 'RICEHPIOSLR_CTSIA',
#   'key': 'PAAL',
#   'subkey': '0',
#   'date': '2020-11-02',
#   'updated': 1661180053156,
#   'changeOverTime': -0.1622206183507479,
#   'marketChangeOverTime': -0.16469215999231887,
#   'label': 'Nov 2, 20',
#   'change': -0.09350993635498238},
#  {'close': 111.02,
#   'fclose': 113.7434,
#   'fhigh': 113.428,
#   'flow': 112.7666,
#   'fopen': 112.1352,
#   'fvolume': 109385277,
#   'high': 113.9,
#   'low': 110.06,
#   'open': 111.26,
#   'symbol': 'AAPL',
#   'uclose': 112.63,
#   'uhigh': 114.43,
#   'ulow': 109.18,
#   'uopen': 111.11,
#   'uvolume': 108771375,
#   'volume': 112541425,
#   'id': 'OIPACSC_IHESRTILR',
#   'key': 'AALP',
#   'subkey': '0',
#   'date': '2020-11-03',
#   'updated': 1646894241176,
#   'changeOverTime': -0.14523382682181446,
#   'marketChangeOverTime': -0.14922903503721643,
#   'label': 'Nov 3, 20',
#   'change': 1.750689409313046},
#  {'close': 115.26,
#   'fclose': 119.809,
#   'fhigh': 118.3161,
#   'flow': 114.1496,
#   'fopen': 117.5954,
#   'fvolume': 144250086,
#   'high': 120.33,
#   'low': 117.46,
#   'open': 116.95,
#   'symbol': 'AAPL',
#   'uclose': 115.63,
#   'uhigh': 120.23,
#   'ulow': 113.37,
#   'uopen': 117.76,
#   'uvolume': 141974385,
#   'volume': 142891356,
#   'id': 'OCTLIAEP_HCSRISIR',
#   'key': 'AALP',
#   'subkey': '0',
#   'date': '2020-11-04',
#   'updated': 1686980741616,
#   'changeOverTime': -0.11432545001418064,
#   'marketChangeOverTime': -0.11252294034913186,
#   'label': 'Nov 4, 20',
#   'change': 4.590497025845783},
#  {'close': 121.31,
#   'fclose': 121.641,
#   'fhigh': 123.441,
#   'flow': 121.7021,
#   'fopen': 123.2533,
#   'fvolume': 127033159,
#   'high': 121.81,
#   'low': 119.1802,
#   'open': 118.03,
#   'symbol': 'AAPL',
#   'uclose': 120.48,
#   'uhigh': 123.36,
#   'ulow': 119.8209,
#   'uopen': 121.47,
#   'uvolume': 130055939,
#   'volume': 128011198,
#   'id': 'LHCSTORASIICPRE_I',
#   'key': 'APAL',
#   'subkey': '0',
#   'date': '2020-11-05',
#   'updated': 1680137109529,
#   'changeOverTime': -0.07938397179769975,
#   'marketChangeOverTime': -0.07854899134236233,
#   'label': 'Nov 5, 20',
#   'change': 4.184475003747076},
#  {'close': 119.2,
#   'fclose': 122.1,
#   'fhigh': 122.4,
#   'flow': 117.56,
#   'fopen': 120.06,
#   'fvolume': 115931326,
#   'high': 120.4,
#   'low': 121.74,
#   'open': 121.29,
#   'symbol': 'AAPL',
#   'uclose': 124.12,
#   'uhigh': 123.9,
#   'ulow': 117.21,
#   'uopen': 120.13,
#   'uvolume': 118864003,
#   'volume': 118212816,
#   'id': 'I_ROSTEIIPCARHSLC',
#   'key': 'LPAA',
#   'subkey': '0',
#   'date': '2020-11-06',
#   'updated': 1655910862166,
#   'changeOverTime': -0.08033799523177426,
#   'marketChangeOverTime': -0.08065594436687672,
#   'label': 'Nov 6, 20',
#   'change': -0.3472555525388984},
#  {'close': 118.87,
#   'fclose': 121.19,
#   'fhigh': 123.9,
#   'flow': 117.7,
#   'fopen': 124.3,
#   'fvolume': 158064708,
#   'high': 126.08,
#   'low': 120.58,
#   'open': 125.5,
#   'symbol': 'AAPL',
#   'uclose': 117.14,
#   'uhigh': 126.44,
#   'ulow': 120.17,
#   'uopen': 126.1,
#   'uvolume': 156871237,
#   'volume': 161690418,
#   'id': 'CHRA_CIIPEOSILRST',
#   'key': 'LPAA',
#   'subkey': '0',
#   'date': '2020-11-09',
#   'updated': 1649360721800,
#   'changeOverTime': -0.1004348530207101,
#   'marketChangeOverTime': -0.0990356744572261,
#   'label': 'Nov 9, 20',
#   'change': -2.4262440370181166},
#  {'close': 118.05,
#   'fclose': 118.99,
#   'fhigh': 119.15,
#   'flow': 116.04,
#   'fopen': 116.38,
#   'fvolume': 140475062,
#   'high': 123.28,
#   'low': 114.79,
#   'open': 120.32,
#   'symbol': 'AAPL',
#   'uclose': 121.01,
#   'uhigh': 122.13,
#   'ulow': 118.94,
#   'uopen': 118.71,
#   'uvolume': 138732603,
#   'volume': 142940645,
#   'id': 'ATHCIROISSL_PICRE',
#   'key': 'APLA',
#   'subkey': '0',
#   'date': '2020-11-10',
#   'updated': 1637251125213,
#   'changeOverTime': -0.10266567195117403,
#   'marketChangeOverTime': -0.10347370582903911,
#   'label': 'Nov 10, 20',
#   'change': -0.3670463364585055},
#  {'close': 123.82,
#   'fclose': 121.63,
#   'fhigh': 124.42,
#   'flow': 119.09,
#   'fopen': 118.23,
#   'fvolume': 113331415,
#   'high': 124.11,
#   'low': 121.36,
#   'open': 117.57,
#   'symbol': 'AAPL',
#   'uclose': 124.38,
#   'uhigh': 120.82,
#   'ulow': 117.13,
#   'uopen': 117.82,
#   'uvolume': 114307418,
#   'volume': 115375569,
#   'id': '_SSPTERILCRIIHACO',
#   'key': 'APLA',
#   'subkey': '0',
#   'date': '2020-11-11',
#   'updated': 1684528796521,
#   'changeOverTime': -0.077619592042489,
#   'marketChangeOverTime': -0.076002934838656,
#   'label': 'Nov 11, 20',
#   'change': 3.579893321190106},
#  {'close': 121.83,
#   'fclose': 123.81,
#   'fhigh': 122.13,
#   'flow': 123.15,
#   'fopen': 119.71,
#   'fvolume': 104190912,
#   'high': 126.2,
#   'low': 123.47,
#   'open': 124.81,
#   'symbol': 'AAPL',
#   'uclose': 119.63,
#   'uhigh': 123.15,
#   'ulow': 120.66,
#   'uopen': 121.88,
#   'uvolume': 107071979,
#   'volume': 107888044,
#   'id': 'SI_CORLIAHCTRIPES',
#   'key': 'PALA',
#   'subkey': '0',
#   'date': '2020-11-12',
#   'updated': 1635463446290,
#   'changeOverTime': -0.07788481274466785,
#   'marketChangeOverTime': -0.07919688027374909,
#   'label': 'Nov 12, 20',
#   'change': -0.28134292063684097},
#  {'close': 124.4,
#   'fclose': 123.2,
#   'fhigh': 124.5642,
#   'flow': 122.85,
#   'fopen': 120.39,
#   'fvolume': 84399674,
#   'high': 124.1891,
#   'low': 119.51,
#   'open': 122.79,
#   'symbol': 'AAPL',
#   'uclose': 119.42,
#   'uhigh': 123.3971,
#   'ulow': 121.36,
#   'uopen': 124.58,
#   'uvolume': 84690802,
#   'volume': 83361939,
#   'id': 'SAL_RPIERCOIIHTSC',
#   'key': 'LAPA',
#   'subkey': '0',
#   'date': '2020-11-13',
#   'updated': 1618471936555,
#   'changeOverTime': -0.07952160771923952,
#   'marketChangeOverTime': -0.07675431862532198,
#   'label': 'Nov 13, 20',
#   'change': 0.05007765106261452},
#  {'close': 125.2,
#   'fclose': 125.9,
#   'fhigh': 121.18,
#   'flow': 119.528,
#   'fopen': 122.3,
#   'fvolume': 92397635,
#   'high': 121.26,
#   'low': 121.411,
#   'open': 119.26,
#   'symbol': 'AAPL',
#   'uclose': 122.5,
#   'uhigh': 121.78,
#   'ulow': 119.814,
#   'uopen': 118.96,
#   'uvolume': 95241337,
#   'volume': 91769834,
#   'id': 'A_ICIIRESCHLRPOST',
#   'key': 'PLAA',
#   'subkey': '0',
#   'date': '2020-11-16',
#   'updated': 1623955530320,
#   'changeOverTime': -0.06886238131451632,
#   'marketChangeOverTime': -0.06834869161393797,
#   'label': 'Nov 16, 20',
#   'change': 1.047996115061089},
#  {'close': 120.32,
#   'fclose': 120.31,
#   'fhigh': 124.767,
#   'flow': 121.49,
#   'fopen': 123.63,
#   'fvolume': 76098011,
#   'high': 122.8088,
#   'low': 123.12,
#   'open': 125.03,
#   'symbol': 'AAPL',
#   'uclose': 121.4,
#   'uhigh': 121.0466,
#   'ulow': 122.21,
#   'uopen': 124.59,
#   'uvolume': 77223827,
#   'volume': 75691873,
#   'id': 'PHSRARLSCOII_ITEC',
#   'key': 'APAL',
#   'subkey': '0',
#   'date': '2020-11-17',
#   'updated': 1662183831013,
#   'changeOverTime': -0.07791653630237934,
#   'marketChangeOverTime': -0.07523431088976747,
#   'label': 'Nov 17, 20',
#   'change': -0.9298019170385752},
#  {'close': 122.91,
#   'fclose': 122.44,
#   'fhigh': 124.67,
#   'flow': 120.43,
#   'fopen': 120,
#   'fvolume': 76405225,
#   'high': 121.39,
#   'low': 121.71,
#   'open': 118.41,
#   'symbol': 'AAPL',
#   'uclose': 121.07,
#   'uhigh': 124.06,
#   'ulow': 121.84,
#   'uopen': 120.03,
#   'uvolume': 77408711,
#   'volume': 76321881,
#   'id': 'RICIHOESRI_TCLPSA',
#   'key': 'LAAP',
#   'subkey': '0',
#   'date': '2020-11-19',
#   'updated': 1639665939454,
#   'changeOverTime': -0.08246073724959202,
#   'marketChangeOverTime': -0.08200355163768899,
#   'label': 'Nov 19, 20',
#   'change': -0.75},
#  {'close': 121.35,
#   'fclose': 122.03,
#   'fhigh': 120.51,
#   'flow': 119.98,
#   'fopen': 123.12,
#   'fvolume': 76703974,
#   'high': 124.21,
#   'low': 117.34,
#   'open': 119.67,
#   'symbol': 'AAPL',
#   'uclose': 118.03,
#   'uhigh': 123.33,
#   'ulow': 121.23,
#   'uopen': 120.11,
#   'uvolume': 76799335,
#   'volume': 74523222,
#   'id': 'IISRTLP_ASHCCIORE',
#   'key': 'ALAP',
#   'subkey': '0',
#   'date': '2020-11-20',
#   'updated': 1612107909854,
#   'changeOverTime': -0.09280293813464782,
#   'marketChangeOverTime': -0.09198084848717948,
#   'label': 'Nov 20, 20',
#   'change': -1.3080432303716762},
#  {'close': 117.2,
#   'fclose': 114.53,
#   'fhigh': 120.4789,
#   'flow': 118.6,
#   'fopen': 121.04,
#   'fvolume': 129955015,
#   'high': 121.0165,
#   'low': 114.26,
#   'open': 121.42,
#   'symbol': 'AAPL',
#   'uclose': 116.97,
#   'uhigh': 120.5593,
#   'ulow': 118.72,
#   'uopen': 120.33,
#   'uvolume': 130418476,
#   'volume': 133970285,
#   'id': 'ILSCC_HOITIAERRSP',
#   'key': 'LPAA',
#   'subkey': '0',
#   'date': '2020-11-23',
#   'updated': 1658735808138,
#   'changeOverTime': -0.12000823051674568,
#   'marketChangeOverTime': -0.12159481939641346,
#   'label': 'Nov 23, 20',
#   'change': -3.610126792966805},
#  {'close': 117.44,
#   'fclose': 118.7,
#   'fhigh': 118.72,
#   'flow': 115.37,
#   'fopen': 118.02,
#   'fvolume': 116363207,
#   'high': 118.34,
#   'low': 117.02,
#   'open': 117.43,
#   'symbol': 'AAPL',
#   'uclose': 119.93,
#   'uhigh': 119.98,
#   'ulow': 115.78,
#   'uopen': 117.15,
#   'uvolume': 119546553,
#   'volume': 118997237,
#   'id': 'IICLSSORIETH_PARC',
#   'key': 'PAAL',
#   'subkey': '0',
#   'date': '2020-11-24',
#   'updated': 1644826607212,
#   'changeOverTime': -0.11152920416270264,
#   'marketChangeOverTime': -0.11240443908449241,
#   'label': 'Nov 24, 20',
#   'change': 1.3302139953872985},
#  {'close': 121.3,
#   'fclose': 116.39,
#   'fhigh': 120.68,
#   'flow': 119.14,
#   'fopen': 118.92,
#   'fvolume': 77919887,
#   'high': 121.07,
#   'low': 119.85,
#   'open': 119.7,
#   'symbol': 'AAPL',
#   'uclose': 116.95,
#   'uhigh': 122.4,
#   'ulow': 118.8,
#   'uopen': 118.15,
#   'uvolume': 78139019,
#   'volume': 79094798,
#   'id': 'LOCATRH_SISEPICRI',
#   'key': 'ALAP',
#   'subkey': '0',
#   'date': '2020-11-25',
#   'updated': 1631675630584,
#   'changeOverTime': -0.1016983985797999,
#   'marketChangeOverTime': -0.1036696894060639,
#   'label': 'Nov 25, 20',
#   'change': 0.8611083678438144},
#  {'close': 121.35,
#   'fclose': 117.97,
#   'fhigh': 123.27,
#   'flow': 117.12,
#   'fopen': 120.65,
#   'fvolume': 47658298,
#   'high': 119.56,
#   'low': 119.85,
#   'open': 118.61,
#   'symbol': 'AAPL',
#   'uclose': 121.01,
#   'uhigh': 118.81,
#   'ulow': 119.55,
#   'uopen': 120.65,
#   'uvolume': 46841007,
#   'volume': 46827783,
#   'id': 'CLTIHCSPO_IIRRASE',
#   'key': 'AAPL',
#   'subkey': '0',
#   'date': '2020-11-27',
#   'updated': 1661700765614,
#   'changeOverTime': -0.1009100500578385,
#   'marketChangeOverTime': -0.09693836808309689,
#   'label': 'Nov 27, 20',
#   'change': 0.5865970039616366}]

# %%
pd.DataFrame.from_dict(json['AAPL']['chart']).columns
# Out:
# Index(['close', 'fclose', 'fhigh', 'flow', 'fopen', 'fvolume', 'high', 'low',
#        'open', 'symbol', 'uclose', 'uhigh', 'ulow', 'uopen', 'uvolume',
#        'volume', 'id', 'key', 'subkey', 'date', 'updated', 'changeOverTime',
#        'marketChangeOverTime', 'label', 'change'],
#       dtype='object')

# %%
def json_to_pandas(out):
    if len(symbols) > 1:
        out = {
            (symbol, pd.to_datetime(day["date"])): day
            for symbol in out
            for day in out[symbol]["chart"]
        }
        result = pd.DataFrame.from_dict(out, orient='index')
        idx = pd.IndexSlice
        result = result.loc[idx[:, start : end], :]
    else:
        out = {entr["date"]: entr for entr in out[symbols[0]]["chart"]}
        result = pd.DataFrame.from_dict(out, orient="columns").drop("date").T
        result.index = pd.to_datetime(result.index)
        result = result.loc[start : end, :]
    return result

# %%
out = {
    (symbol, day["date"]): day
    for symbol in json
    for day in json[symbol]["chart"]
}
result = pd.DataFrame.from_dict(out, orient='index')#.drop("date")

# %%
result.index[0].type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-2e2073eb1443> in <module>
# ----> 1 result.index[0].type
#
# AttributeError: 'tuple' object has no attribute 'type'

# %%
json_to_pandas(json)
# Out:
#                    close   fclose    fhigh     flow    fopen    fvolume  \
# AAPL 2020-10-01   118.85  122.118  121.776  119.704  119.711  119927784
#      2020-10-02    113.5  113.356  117.491  114.942  113.528  150988503
#      2020-10-05    120.4  119.125  120.177  114.598  117.182  109077520
#      2020-10-06   115.95  117.533   116.42  117.174  115.504  166276167
#      2020-10-07   116.88  115.526  119.474  115.162   119.29   98119280
# ...                  ...      ...      ...      ...      ...        ...
# GOOG 2020-11-20  1803.06  1798.91     1860  1827.97  1814.01    2353572
#      2020-11-23  1796.37  1767.02   1810.3  1801.48   1778.2    2197919
#      2020-11-24  1824.21  1796.98   1808.8  1757.34   1762.7    1621833
#      2020-11-25  1778.12  1788.26  1825.92  1789.22  1825.03    1097443
#      2020-11-27  1880.39  1877.05     1882  1846.76  1840.12     894902
#
#                    high      low     open symbol  ...    uvolume     volume  \
# AAPL 2020-10-01  121.43   119.34   119.01   AAPL  ...  119787125  117863570
#      2020-10-02   116.9   114.41    114.3   AAPL  ...  151580156  147795286
#      2020-10-05  119.89   113.84   118.04   AAPL  ...  111292924  106493112
#      2020-10-06  121.35   114.73    117.1   AAPL  ...  166509237  166354275
#      2020-10-07  117.32   115.08   114.76   AAPL  ...   97489393   97640934
# ...                 ...      ...      ...    ...  ...        ...        ...
# GOOG 2020-11-20    1833  1742.13  1827.66   GOOG  ...    2332062    2333171
#      2020-11-23  1793.2  1740.12   1821.4   GOOG  ...    2244387    2217493
#      2020-11-24  1793.4  1756.27   1776.2   GOOG  ...    1629109    1588832
#      2020-11-25  1788.1  1783.09   1789.5   GOOG  ...    1051881    1054563
#      2020-11-27    1827  1807.43  1840.38   GOOG  ...     906853     891596
#
#                                 id   key subkey        updated changeOverTime  \
# AAPL 2020-10-01  IESPCCLHR_IAOISTR  AAPL      0  1657367821678     -0.0988582
#      2020-10-02  HIOCTLEARRISC_PIS  ALPA      0  1609776141353      -0.126203
#      2020-10-05  IRTIESRSHI_LAPCCO  LAAP      0  1621150615937     -0.0987807
#      2020-10-06  _HERPLRSTOCIASIIC  PAAL      0  1665448371511      -0.126607
#      2020-10-07  C_POLREHRIIICTSAS  PAAL      0  1638772451694       -0.11019
# ...                            ...   ...    ...            ...            ...
# GOOG 2020-11-20  ICC_HISTSAIPLOERR  OGGO      0  1634988141568      0.0664042
#      2020-11-23  AIIRPHCOISRC_LSTE  GGOO      0  1666260234269       0.062919
#      2020-11-24  LEROHPTISISCCIRA_  OGOG      0  1682680380197      0.0855063
#      2020-11-25  IHRCSEARCP_ITSLIO  OOGG      0  1674447895222       0.088048
#      2020-11-27  TCHAER_IPILSCSOIR  OOGG      0  1632201712104       0.101395
#
#                 marketChangeOverTime       label    change
# AAPL 2020-10-01           -0.0980749   Oct 1, 20  0.995447
#      2020-10-02            -0.126489   Oct 2, 20  -3.77295
#      2020-10-05            -0.097514   Oct 5, 20    3.5943
#      2020-10-06            -0.129213   Oct 6, 20  -3.42681
#      2020-10-07            -0.111806   Oct 7, 20   2.01111
# ...                              ...         ...       ...
# GOOG 2020-11-20            0.0688907  Nov 20, 20  -22.3366
#      2020-11-23            0.0634248  Nov 23, 20  -7.58948
#      2020-11-24            0.0853352  Nov 24, 20   35.6868
#      2020-11-25            0.0853383  Nov 25, 20   2.58498
#      2020-11-27             0.101023  Nov 27, 20   22.7629
#
# [80 rows x 24 columns]
