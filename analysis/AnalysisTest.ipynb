# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
import requests_cache
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
import json
import time
import warnings
import tables

from datetime import datetime, date
from dateutil.relativedelta import relativedelta
from iexfinance.refdata import get_symbols, get_iex_symbols
from iexfinance.stocks import get_historical_data
from iexfinance.altdata import get_social_sentiment
from iexfinance.stocks import Stock

sys.path.append("./src")
from per_high_low import get_min_max_dfs,compute_stocks_near_max_min,save_daily_results

# %%
os.environ["IEX_API_VERSION"] = "iexcloud-sandbox"
FIRST_SYMBOL_IDX = 0
LAST_SYMBOL_IDX = 5
IEX_TOKEN = "Tpk_57fa15c2c86b4dadbb31e0c1ad1db895"
NUM_YEARS_HISTORY = 4
END_DATE_OFFSET = 0

# %%
all_symbols = get_symbols(token=IEX_TOKEN)
symbols = all_symbols[FIRST_SYMBOL_IDX:LAST_SYMBOL_IDX]

# %%
(df_min, df_max) = get_min_max_dfs(symbols)
# Out:
# A: Trying to access historical data between 2016-12-28 00:00:00 and 2020-12-28 00:00:00.
# A: Data is catched between 2016-12-28 00:00:00 and 2020-12-28 00:00:00.
# Successfully processed A
# AA: Trying to access historical data between 2016-12-28 00:00:00 and 2020-12-28 00:00:00.
# AA: Data is catched between 2016-12-28 00:00:00 and 2020-12-28 00:00:00.
# Successfully processed AA
# AAA: Trying to access historical data between 2016-12-28 00:00:00 and 2020-12-28 00:00:00.
# AAA: Data is catched between 2016-12-28 00:00:00 and 2020-12-28 00:00:00.
# Successfully processed AAA
# AAAU: Trying to access historical data between 2016-12-28 00:00:00 and 2020-12-28 00:00:00.
# AAAU: Data is catched between 2016-12-28 00:00:00 and 2020-12-28 00:00:00.
# Successfully processed AAAU
# AACG: Trying to access historical data between 2016-12-28 00:00:00 and 2020-12-28 00:00:00.
# AACG: Data is catched between 2016-12-28 00:00:00 and 2020-12-28 00:00:00.
# Successfully processed AACG

# %%
df = compute_stocks_near_max_min(df_max, df_min)

# %%
df["near_max"].mean()
# Out:
# 0.4631258278145695

# %%
save_daily_results(df)
# Out:
# Blob dev_per_high_low_latest.png is publicly accessible at https://storage.googleapis.com/market-navigator-data/dev_per_high_low_latest.png
# Blob dev_per_high_low_latest.json is publicly accessible at https://storage.googleapis.com/market-navigator-data/dev_per_high_low_latest.json

# %%
list(all_symbols['symbol']).index("SLVP")
# Out:
# 7659
